# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.set_context("paper")
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches

from tqdm import tqdm # progress bars :)
tqdm.pandas()

from sourmash.lca import lca_utils
from sourmash.tax import tax_utils

# %%
a85_file = "big_file_cont_ani_85-90-95/gtdb-rs202.nucleotide-k31-scaled1000.recalc-ani.cut.csvani_85.txt"
a90_file = "big_file_cont_ani_85-90-95/gtdb-rs202.nucleotide-k31-scaled1000.recalc-ani.cut.csvani_90.txt"
a95_file = "big_file_cont_ani_85-90-95/gtdb-rs202.nucleotide-k31-scaled1000.recalc-ani.cut.csvani_95.txt"

#c85_file = "big_file_cont_ani_85-90-95/gtdb-rs202.nucleotide-k31-scaled1000.recalc-ani.cut.csvcont_85.txt"
#c90_file = "big_file_cont_ani_85-90-95/gtdb-rs202.nucleotide-k31-scaled1000.recalc-ani.cut.csvcont_90.txt"
#c95_file = "big_file_cont_ani_85-90-95/gtdb-rs202.nucleotide-k31-scaled1000.recalc-ani.cut.csvcont_95.txt"

# %% [markdown]
# # Look at 95% ANI clustering:
# (k=31, scaled=100, gtdb-rs202)

# %% [markdown]
# ### load 95% ani clustering file:

# %%
#a95_clusters = [x.strip().split(',') for x in open(a95_file, 'r')]
#a95_clusters[1]
a95 = pd.read_csv(a95_file, sep='\t', header=None, index_col=False, names = ["cluster_idents"])
a95_head = a95.head()
a95_head
# Out:
#                                       cluster_idents
# 0  GCA_000006155,GCF_002565765,GCF_001941885,GCF_...
# 1  GCF_000178895,GCA_000007325,GCA_001296185,GCF_...
# 2  GCF_003299955,GCA_000007385,GCF_003300055,GCF_...
# 3                                      GCA_000008085
# 4  GCA_002554195,GCA_000009845,GCF_000803325,GCF_...

# %% [markdown]
# ### read in lineages

# %%
taxonomy_csv = "gtdb-rs202.taxonomy.v2.csv"
tax = pd.read_csv(taxonomy_csv)
tax['lineage'] = tax["superkingdom"] + ',' + tax["phylum"] + ',' + tax["class"] + ',' + tax["order"] + ',' + tax["family"] + ',' + tax["genus"] + ',' + tax["species"]
tax['smash_lin'] = tax['lineage'].apply(lambda x: lca_utils.make_lineage(x))
tax['split_ident'] = tax['ident'].str.split('.', expand=True)[0]
tax.head()
# Out:
#              ident superkingdom             phylum                   class  \
# 0  GCF_014075335.1  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 1  GCF_002310555.1  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 2  GCF_900013275.1  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 3  GCF_000168095.1  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
# 4  GCF_002459845.1  d__Bacteria  p__Proteobacteria  c__Gammaproteobacteria
#
#                  order                 family           genus  \
# 0  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
# 1  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
# 2  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
# 3  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
# 4  o__Enterobacterales  f__Enterobacteriaceae  g__Escherichia
#
#                    species                                            lineage  \
# 0  s__Escherichia flexneri  d__Bacteria,p__Proteobacteria,c__Gammaproteoba...
# 1  s__Escherichia flexneri  d__Bacteria,p__Proteobacteria,c__Gammaproteoba...
# 2  s__Escherichia flexneri  d__Bacteria,p__Proteobacteria,c__Gammaproteoba...
# 3  s__Escherichia flexneri  d__Bacteria,p__Proteobacteria,c__Gammaproteoba...
# 4  s__Escherichia flexneri  d__Bacteria,p__Proteobacteria,c__Gammaproteoba...
#
#                                            smash_lin    split_ident
# 0  ((superkingdom, d__Bacteria), (phylum, p__Prot...  GCF_014075335
# 1  ((superkingdom, d__Bacteria), (phylum, p__Prot...  GCF_002310555
# 2  ((superkingdom, d__Bacteria), (phylum, p__Prot...  GCF_900013275
# 3  ((superkingdom, d__Bacteria), (phylum, p__Prot...  GCF_000168095
# 4  ((superkingdom, d__Bacteria), (phylum, p__Prot...  GCF_002459845

# %%
taxD = tax.set_index('split_ident').to_dict()['smash_lin']

# %%
def count_and_find_lca_test(row, lineages=taxD):
    all_idents = row['cluster_idents']
    ident_list = all_idents.split(',')
    row['cluster_len'] = len(ident_list)
    all_lineages=[]
    for ident in ident_list:
        lineage = taxD[ident]
        all_lineages.append(lineage)
    lca_tree = lca_utils.build_tree(all_lineages)
    lca = lca_utils.find_lca(lca_tree)
    row['cluster_lca'] = lca
    row['cluster_lca_pretty'] = lca_utils.display_lineage(lca[0])
    row['lca_rank'] = lca[0][-1].rank
    print(lca[0])
    print(lca[1])
    print(row['cluster_lca_pretty'])
    return row

# %%
a95_head.progress_apply(count_and_find_lca_test, axis=1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 158.15it/s]
# (LineagePair(rank='superkingdom', name='d__Bacteria'), LineagePair(rank='phylum', name='p__Firmicutes'), LineagePair(rank='class', name='c__Bacilli'), LineagePair(rank='order', name='o__Bacillales'), LineagePair(rank='family', name='f__Bacillaceae_G'), LineagePair(rank='genus', name='g__Bacillus_A'))
# 12
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacillales;f__Bacillaceae_G;g__Bacillus_A
# (LineagePair(rank='superkingdom', name='d__Bacteria'), LineagePair(rank='phylum', name='p__Fusobacteriota'), LineagePair(rank='class', name='c__Fusobacteriia'), LineagePair(rank='order', name='o__Fusobacteriales'), LineagePair(rank='family', name='f__Fusobacteriaceae'), LineagePair(rank='genus', name='g__Fusobacterium'), LineagePair(rank='species', name='s__Fusobacterium nucleatum'))
# 0
# d__Bacteria;p__Fusobacteriota;c__Fusobacteriia;o__Fusobacteriales;f__Fusobacteriaceae;g__Fusobacterium;s__Fusobacterium nucleatum
# (LineagePair(rank='superkingdom', name='d__Bacteria'), LineagePair(rank='phylum', name='p__Proteobacteria'), LineagePair(rank='class', name='c__Gammaproteobacteria'), LineagePair(rank='order', name='o__Xanthomonadales'), LineagePair(rank='family', name='f__Xanthomonadaceae'), LineagePair(rank='genus', name='g__Xanthomonas'), LineagePair(rank='species', name='s__Xanthomonas oryzae'))
# 0
# d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Xanthomonadales;f__Xanthomonadaceae;g__Xanthomonas;s__Xanthomonas oryzae
# (LineagePair(rank='superkingdom', name='d__Archaea'), LineagePair(rank='phylum', name='p__Nanoarchaeota'), LineagePair(rank='class', name='c__Nanoarchaeia'), LineagePair(rank='order', name='o__Nanoarchaeales'), LineagePair(rank='family', name='f__Nanoarchaeaceae'), LineagePair(rank='genus', name='g__Nanoarchaeum'), LineagePair(rank='species', name='s__Nanoarchaeum equitans'))
# 0
# d__Archaea;p__Nanoarchaeota;c__Nanoarchaeia;o__Nanoarchaeales;f__Nanoarchaeaceae;g__Nanoarchaeum;s__Nanoarchaeum equitans
# (LineagePair(rank='superkingdom', name='d__Bacteria'), LineagePair(rank='phylum', name='p__Firmicutes'), LineagePair(rank='class', name='c__Bacilli'), LineagePair(rank='order', name='o__Acholeplasmatales'), LineagePair(rank='family', name='f__Acholeplasmataceae'), LineagePair(rank='genus', name='g__Phytoplasma'))
# 2
# d__Bacteria;p__Firmicutes;c__Bacilli;o__Acholeplasmatales;f__Acholeplasmataceae;g__Phytoplasma
#                                       cluster_idents  cluster_len  \
# 0  GCA_000006155,GCF_002565765,GCF_001941885,GCF_...          961
# 1  GCF_000178895,GCA_000007325,GCA_001296185,GCF_...           12
# 2  GCF_003299955,GCA_000007385,GCF_003300055,GCF_...          360
# 3                                      GCA_000008085            1
# 4  GCA_002554195,GCA_000009845,GCF_000803325,GCF_...           11
#
#                                          cluster_lca  \
# 0  (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 1  (((superkingdom, d__Bacteria), (phylum, p__Fus...
# 2  (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 3  (((superkingdom, d__Archaea), (phylum, p__Nano...
# 4  (((superkingdom, d__Bacteria), (phylum, p__Fir...
#
#                                   cluster_lca_pretty lca_rank
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacill...    genus
# 1  d__Bacteria;p__Fusobacteriota;c__Fusobacteriia...  species
# 2  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# 3  d__Archaea;p__Nanoarchaeota;c__Nanoarchaeia;o_...  species
# 4  d__Bacteria;p__Firmicutes;c__Bacilli;o__Achole...    genus

# %%
def count_and_find_lca(row, lineages=taxD):
    all_idents = row['cluster_idents']
    ident_list = all_idents.split(',')
    row['cluster_len'] = len(ident_list)
    all_lineages=[]
    for ident in ident_list:
        lineage = taxD[ident]
        all_lineages.append(lineage)
    lca_tree = lca_utils.build_tree(all_lineages)
    lca = lca_utils.find_lca(lca_tree)
    row['cluster_lca'] = lca
    row['cluster_lca_pretty'] = lca_utils.display_lineage(lca[0])
    row['lca_rank'] = lca[0][-1].rank
    return row

# %%
a95 = a95.progress_apply(count_and_find_lca, axis=1)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 43805/43805 [01:08<00:00, 639.99it/s]

# %%
a95.shape
# Out:
# (43805, 5)

# %%
a95.head()
# Out:
#                                       cluster_idents  cluster_len  \
# 0  GCA_000006155,GCF_002565765,GCF_001941885,GCF_...          961
# 1  GCF_000178895,GCA_000007325,GCA_001296185,GCF_...           12
# 2  GCF_003299955,GCA_000007385,GCF_003300055,GCF_...          360
# 3                                      GCA_000008085            1
# 4  GCA_002554195,GCA_000009845,GCF_000803325,GCF_...           11
#
#                                          cluster_lca  \
# 0  (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 1  (((superkingdom, d__Bacteria), (phylum, p__Fus...
# 2  (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 3  (((superkingdom, d__Archaea), (phylum, p__Nano...
# 4  (((superkingdom, d__Bacteria), (phylum, p__Fir...
#
#                                   cluster_lca_pretty lca_rank
# 0  d__Bacteria;p__Firmicutes;c__Bacilli;o__Bacill...    genus
# 1  d__Bacteria;p__Fusobacteriota;c__Fusobacteriia...  species
# 2  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# 3  d__Archaea;p__Nanoarchaeota;c__Nanoarchaeia;o_...  species
# 4  d__Bacteria;p__Firmicutes;c__Bacilli;o__Achole...    genus

# %%
# total identifiers we're looking at:
total_n_idents = a95['cluster_len'].sum()
total_n_idents
# Out:
# 258406

# %%
# how many are singleton clusters? ~27k
a95[a95['cluster_len'] == 1]
# Out:
#       cluster_idents  cluster_len  \
# 3      GCA_000008085            1
# 14     GCA_000015805            1
# 22     GCA_000024525            1
# 27     GCA_000145985            1
# 30     GCA_000147015            1
# ...              ...          ...
# 43799  GCF_903970965            1
# 43801  GCF_903994035            1
# 43802  GCF_903994045            1
# 43803  GCF_904061905            1
# 43804  GCF_904067545            1
#
#                                              cluster_lca  \
# 3      (((superkingdom, d__Archaea), (phylum, p__Nano...
# 14     (((superkingdom, d__Archaea), (phylum, p__Ther...
# 22     (((superkingdom, d__Bacteria), (phylum, p__Bac...
# 27     (((superkingdom, d__Archaea), (phylum, p__Ther...
# 30     (((superkingdom, d__Bacteria), (phylum, p__Pro...
# ...                                                  ...
# 43799  (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 43801  (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 43802  (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 43803  (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 43804  (((superkingdom, d__Archaea), (phylum, p__Meth...
#
#                                       cluster_lca_pretty lca_rank
# 3      d__Archaea;p__Nanoarchaeota;c__Nanoarchaeia;o_...  species
# 14     d__Archaea;p__Thermoproteota;c__Thermoproteia;...  species
# 22     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  species
# 27     d__Archaea;p__Thermoproteota;c__Thermoproteia;...  species
# 30     d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# ...                                                  ...      ...
# 43799  d__Bacteria;p__Proteobacteria;c__Alphaproteoba...  species
# 43801  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphy...  species
# 43802  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphy...  species
# 43803  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# 43804  d__Archaea;p__Methanobacteriota;c__Thermococci...  species
#
# [27792 rows x 5 columns]

# %%
# how many have lca rank of species?
a95[a95['lca_rank'] == 'species']
# Out:
#                                           cluster_idents  cluster_len  \
# 1      GCF_000178895,GCA_000007325,GCA_001296185,GCF_...           12
# 2      GCF_003299955,GCA_000007385,GCF_003300055,GCF_...          360
# 3                                          GCA_000008085            1
# 5                            GCA_013178385,GCA_000010565            2
# 7      GCA_000013525,GCF_014050235,GCA_000167435,GCF_...         2136
# ...                                                  ...          ...
# 43800                        GCF_903986915,GCF_903986855            2
# 43801                                      GCF_903994035            1
# 43802                                      GCF_903994045            1
# 43803                                      GCF_904061905            1
# 43804                                      GCF_904067545            1
#
#                                              cluster_lca  \
# 1      (((superkingdom, d__Bacteria), (phylum, p__Fus...
# 2      (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 3      (((superkingdom, d__Archaea), (phylum, p__Nano...
# 5      (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 7      (((superkingdom, d__Bacteria), (phylum, p__Fir...
# ...                                                  ...
# 43800  (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 43801  (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 43802  (((superkingdom, d__Bacteria), (phylum, p__Fir...
# 43803  (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 43804  (((superkingdom, d__Archaea), (phylum, p__Meth...
#
#                                       cluster_lca_pretty lca_rank
# 1      d__Bacteria;p__Fusobacteriota;c__Fusobacteriia...  species
# 2      d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# 3      d__Archaea;p__Nanoarchaeota;c__Nanoarchaeia;o_...  species
# 5      d__Bacteria;p__Firmicutes_B;c__Desulfotomaculi...  species
# 7      d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactob...  species
# ...                                                  ...      ...
# 43800  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# 43801  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphy...  species
# 43802  d__Bacteria;p__Firmicutes;c__Bacilli;o__Staphy...  species
# 43803  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...  species
# 43804  d__Archaea;p__Methanobacteriota;c__Thermococci...  species
#
# [41563 rows x 5 columns]

# %%
# lca rank --  cluster length distribution
a95.groupby("lca_rank")['cluster_len'].describe()
# Out:
#                 count         mean         std     min     25%     50%  \
# lca_rank
# family            3.0   329.000000  297.544955     5.0   198.5   392.0
# genus          2237.0    54.978543  660.263627     2.0     3.0     5.0
# order             1.0  1474.000000         NaN  1474.0  1474.0  1474.0
# species       41563.0     3.198903   71.723025     1.0     1.0     1.0
# superkingdom      1.0     2.000000         NaN     2.0     2.0     2.0
#
#                  75%      max
# lca_rank
# family         491.0    590.0
# genus           11.0  23509.0
# order         1474.0   1474.0
# species          2.0  12022.0
# superkingdom     2.0      2.0

# %%
a95[a95["lca_rank"]=="family"]
# Out:
#                                          cluster_idents  cluster_len  \
# 447   GCF_007896815,GCA_900554435,GCA_001915605,GCF_...          392
# 717   GCF_009648935,GCA_012641175,GCF_008370135,GCA_...          590
# 8039  GCF_004124535,GCA_012965015,GCA_012964125,GCA_...            5
#
#                                             cluster_lca  \
# 447   (((superkingdom, d__Bacteria), (phylum, p__Bac...
# 717   (((superkingdom, d__Bacteria), (phylum, p__Pro...
# 8039  (((superkingdom, d__Bacteria), (phylum, p__Mar...
#
#                                      cluster_lca_pretty lca_rank
# 447   d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...   family
# 717   d__Bacteria;p__Proteobacteria;c__Gammaproteoba...   family
# 8039  d__Bacteria;p__Marinisomatota;c__Marinisomatia...   family

# %%
a95[a95["lca_rank"]=="order"]
# Out:
#                                         cluster_idents  cluster_len  \
# 245  GCF_014057765,GCF_014057775,GCF_014057805,GCF_...         1474
#
#                                            cluster_lca  \
# 245  (((superkingdom, d__Bacteria), (phylum, p__Pro...
#
#                                     cluster_lca_pretty lca_rank
# 245  d__Bacteria;p__Proteobacteria;c__Gammaproteoba...    order

# %% [markdown]
# ### BUT, superkindom cluster is actually is species-level!!

# %%
a95[a95["lca_rank"]=="superkingdom"]
# Out:
#                     cluster_idents  cluster_len  \
# 34503  GCF_003265155,GCF_002705755            2
#
#                                cluster_lca cluster_lca_pretty      lca_rank
# 34503  (((superkingdom, d__Bacteria),), 2)        d__Bacteria  superkingdom

# %% [markdown]
# online:
# GCF_003265155: d__Bacteria; p__Actinobacteriota; c__Actinomycetia; o__Actinomycetales; f__Microbacteriaceae; g__Microbacterium; s__Microbacterium esteraromaticum_A
# GCF_002705755: d__Bacteria; p__Actinobacteriota; c__Actinomycetia; o__Actinomycetales; f__Microbacteriaceae; g__Microbacterium; s__Microbacterium esteraromaticum_A
#
# ..which is a **species** cluster!

# %% [markdown]
# ### check gtdb-rs202 taxonomy file:

# %%
tax[tax["split_ident"] == "GCF_003265155"]
# Out:
#                   ident superkingdom         phylum       class  \
# 242915  GCF_003265155.1  d__Bacteria  p__Firmicutes  c__Bacilli
#
#                      order                family               genus  \
# 242915  o__Mycoplasmatales  f__Mycoplasmoidaceae  g__Eperythrozoon_A
#
#                               species  \
# 242915  s__Eperythrozoon_A wenyonii_A
#
#                                                   lineage  \
# 242915  d__Bacteria,p__Firmicutes,c__Bacilli,o__Mycopl...
#
#                                                 smash_lin    split_ident
# 242915  ((superkingdom, d__Bacteria), (phylum, p__Firm...  GCF_003265155

# %%
tax[tax["split_ident"] == "GCF_002705755"]
# Out:
#                   ident superkingdom               phylum             class  \
# 239626  GCF_002705755.3  d__Bacteria  p__Actinobacteriota  c__Actinomycetia
#
#                      order                family              genus  \
# 239626  o__Actinomycetales  f__Microbacteriaceae  g__Microbacterium
#
#                                     species  \
# 239626  s__Microbacterium esteraromaticum_A
#
#                                                   lineage  \
# 239626  d__Bacteria,p__Actinobacteriota,c__Actinomycet...
#
#                                                 smash_lin    split_ident
# 239626  ((superkingdom, d__Bacteria), (phylum, p__Acti...  GCF_002705755

# %%
#check an easy two-cluster:
ex_two_cluster = a95[a95["cluster_idents"] == "GCF_902158745,GCF_902158735"]
ex_two_cluster
# Out:
#                     cluster_idents  cluster_len  \
# 43553  GCF_902158745,GCF_902158735            2
#
#                                              cluster_lca  \
# 43553  (((superkingdom, d__Archaea), (phylum, p__Halo...
#
#                                       cluster_lca_pretty lca_rank
# 43553  d__Archaea;p__Halobacteriota;c__Methanoliparia...    genus

# %%
list(ex_two_cluster["cluster_lca"])
# Out:
# [((LineagePair(rank='superkingdom', name='d__Archaea'),
#    LineagePair(rank='phylum', name='p__Halobacteriota'),
#    LineagePair(rank='class', name='c__Methanoliparia'),
#    LineagePair(rank='order', name='o__Methanoliparales'),
#    LineagePair(rank='family', name='f__Methanoliparaceae'),
#    LineagePair(rank='genus', name='g__Methanolliviera')),
#   2)]
